# %% [markdown]
# <a href="https://colab.research.google.com/github/minwlhtoon/colab/blob/main/AIoT_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Test IoT programming
# github_rerkki

# %%
pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 34.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 24.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/minwlhtoon/datasets/refs/heads/main/monthly.csv', encoding='latin-1')
df.head()
# Out:
#   Source     Year    Mean
# 0   gcag  1850-01 -0.6746
# 1   gcag  1850-02 -0.3334
# 2   gcag  1850-03 -0.5913
# 3   gcag  1850-04 -0.5887
# 4   gcag  1850-05 -0.5088
