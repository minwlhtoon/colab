# %%
# String
#s = "this is a string"
#s = 'this is a string'
s = """Hello world!"""
#s.join (" yes")
n = len (s) 
print (n, s)
# Out:
# 12 Hello world!

# %% [markdown]
# Lists
# L = [1, 2, 3, 4, 5]
# L[0] 	single position, 1
# L[0:3] 	the first three elements 1,2,3
# L[-2:] 	the last two elements 4,5
# del L[2] 	remove element in index 2
# L.append(x) 	insert value x into the list
# L.remove(x) 	remove value x from the list
# L.extend(L2) 	extend list L with the list L2
# L.pop 	simple stack (with append)
# L.sort 	sort the list
# x in L 	does L contain x
# L.index(x) 	index of first occurance

# %%
L = [1, 2, 3, 4, 5]
L [0]
L [0:3]
L [-2:]
#del L [-1]
L.append ("x")
L.remove ('x')
L.extend ('L3')
L.pop
L.sort
'x' in 'L'
#L.index ('x')
print (L)
# Out:
# [1, 2, 3, 4, 5, 'L', '3']

# %% [markdown]
# Tuples
# person = (25, "June", "Smith")	Tuple can have heterogeneous data items.
# print person => (25, 'June', 'Smith')
# print person[2] => Smith	 Tuples can be indexed like arrays or lists

# %%
person = (25, 'June', 'Smith')
print (person)
print (person [2])
# Out:
# (25, 'June', 'Smith')
# Smith

# %% [markdown]
# Sets
# S1 = {1,3,5}	unordered, unchangeable, no duplicate values
# L = [1, 3, 1, 5, 3, 2, 2]
# S2 = set(L)	creates a set from a list above {1,3,5,2}

# %%
S1 = {1,3,5}
L = [1,3,1,5,3,2,2]
S2 = set(L)
print (S2)
# Out:
# {1, 2, 3, 5}

# %% [markdown]
# Control Flows
#    While
#   initialize testing variable
#   while (testing-variable istrue):
#     run indented code
#     increment testing variable
#
#   For	  for variable in list:
#    print variable
#
#   If/
#   Else
#
#   if a < b:
#     do this indented code
#   else:
#    do this code instead

# %%
testing_variable = 0
while (testing_variable < 5):
    print (testing_variable)
    testing_variable = testing_variable + 1
print (testing_variable)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for number in range(0,5):
    print (number)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
if 'a' < 'b':
    print ('Yes')
else:
    print ('No')
# Out:
# Yes

# %% [markdown]
# Functions
#   Defining Functions	  def function_name(input):
#     indented code
#     (4 spaces or 1 tab)
#     return output	  def circle_area(radius):
#     area = 3,14(radius**2)
#     return area
#   Calling Functions	  function_name(input)
#   circle_area(5)  #return 78.5

# %%
def circle_area (radius):
    # Fixed multiplication operator and typo in return
    circle_area = 3.14 * (radius**2)
    return circle_area

# Call the function and store the result
area_result = circle_area(7) 

# Print the stored result
print(area_result)
# Out:
# 153.86

# %% [markdown]
# Input/Output
#   Input/Output
#   print (2+5)
#   7
#   print "Hi"
#   Hi
#
#   age = input("How old are you? ")
#   How old are you? 30
#   print age
#   30
#   Formatting 	  Converting to an integer
#   int(3.14)
#   3
#   Converting into a string
#   'I am' + str(age) ' 'years old.'
#   I am 30 years old

# %%
#print (2+5)
#print ('Hi')

age = input("How old are you?")
# User enters 30
print(age)
# Out:
# 50

# %%
int (3.14)
'I am ' +  str(age) + ' years old.'
# Out:
# 'I am 50 years old.'

# %% [markdown]
# Exceptions
# try:
#     raise TypeError("argument")
# except (RuntimeError, NameError):
#     pass                            # empty instruction
# except:
#     info = sys.exc_info()
#     print(info[0])
#     print(info[1])
#     traceback.print_tb(info[2])
#     raise
# else:
#     ...                             # no exception but before finally
#
# finally:                            # on the way out
#     ...                             # unhandled exc, release resources

# %%
import sys
import traceback

try:
    raise 
except (RuntimeError, NameError):
    pass  # empty instruction
except Exception:
    info = sys.exc_info()
    print(info[0])
    print(info[1])
    traceback.print_tb(info[2])
    raise
else:
    # no exception but before finally
    print("No exception occurred.")
finally:
    # on the way out (always executed)
    print("Releasing resources...")
# Out:
# Releasing resources...

# %%
_2tow= 100
