# %% [markdown]
# Reserved names in the Python language
#
# and	elif	import	return
# as	else	in	try
# assert	except	is	while
# break	finally	lambda	with
# class	for	not	yield
# continue	from	or
# def	global	pass
# del	if	raise

# %%
name = "Min Min"
print(name+" 123")

var1 = "F"
print("You got grade",var1,".")

print("This line will not have an automatic line break. ", end="")
print("So this comes right after the last one.")

number = 4
print("In a quartet, there are",number,"players.", sep=" ")

print("Well eat soup.", end = " And spam!")
# Out:
# Min Min 123
# You got grade F .
# This line will not have an automatic line break. So this comes right after the last one.
# In a quartet, there are 4 players.
# Well eat soup. And spam!

# %%
text = "This text has a line change.\n This is the next line."
text2 = "This text has a line change.\t"
print(text)
print(text2)

rawtext = repr(text2)
print(rawtext)
# Out:
# This text has a line change.
#  This is the next line.
# This text has a line change.
# 'This text has a line change.\t'

# %%
number1 = 3.5
number2 = 4.123123
number3 = 1234.1231513

number1 = round(number1)
number2 = round(number2,2)
number3 = round(number3,4)
print(number1, number2, number3)
# Out:
# 4 4.12 1234.1232

# %%
print("This is a very big, long and even annoying \
command which takes way too much space and is irritating to handle.")

if True:
    print("This is a very big and long, even annoying\
command which takes way too much space \
and is irritating to handle. And now its full \
of holes.")

#Predefined string
"""This thing here is predefined"""
print('''predefined strings can be also made 
with citatition marks.''')

#Escaping layout characters
#print("So are we supposed to see \ '\\' this or what? What does this \ do?")

print("Timmy O'Toole")
print('He said "Dish is best served cold."')
print("The man cried \"One does not simply walk into Berlin!\"")
print("\n\n\nLine breaks!\n\n\n")
print("Timmy O'Toole")
print("\t1\t2\n\t3\t4\n\t5\t6")
# Out:
# This is a very big, long and even annoying command which takes way too much space and is irritating to handle.
# This is a very big and long, even annoyingcommand which takes way too much space and is irritating to handle. And now its full of holes.
# predefined strings can be also made
# with citatition marks.
# Timmy O'Toole
# He said "Dish is best served cold."
# The man cried "One does not simply walk into Berlin!"
#
#
#
# Line breaks!
#
#
#
# Timmy O'Toole
# 	1	2
# 	3	4
# 	5	6

# %%
givenvalue = input("Write something:")

print(givenvalue)
# Out:
# ff

# %%
height = input("Give your height in cm: ")
print(height)
# Out:
# diow

# %%
# -*- coding: cp1252 -*-
# creates a variable, and saves the user-written
# text as a value to the variable
name = input("What is your name? ")
# prints a greeting message including the name.
print("Hello",name+"!")
print("Nice to see you.")
# Out:
# Hello Kavin!
# Nice to see you.

# %%
value = 42
value = int(value)
value + 10

value * 5
# Out:
# 210

# %%
number = '300'
int(number)
#number + 50 # This would cause an error, because number is a string.

number = 300
int(number)
number + 50
# Out:
# 350

# %%
# -*- coding: cp1252 -*-

bigstring = "Damn the torpedoes, full speed ahead!"
length = len(bigstring)
print("The length if the string is",length,"characters.")
print(bigstring)
slice_1 = bigstring[:15]
slice_2 = bigstring[15:]
slice_3 = bigstring[::2]
slice_4 = bigstring[1]
slice_5 = bigstring[5:26]
slice_6 = bigstring[::-1]
slice_7 = bigstring[-10:]
slice_8 = bigstring[:-10]
slice_9 = bigstring[4:30:2]

print("slice_1: ",slice_1)
print("slice_2: ",slice_2)
print("slice_3: ",slice_3)
print("slice_4: ",slice_4)
print("slice_5: ",slice_5)
print("slice_6: ",slice_6)
print("slice_7: ",slice_7)
print("slice_8: ",slice_8)
print("slice_9: ",slice_9)
# Out:
# The length if the string is 37 characters.
# Damn the torpedoes, full speed ahead!
# slice_1:  Damn the torped
# slice_2:  oes, full speed ahead!
# slice_3:  Dm h opde,fl pe ha!
# slice_4:  a
# slice_5:  the torpedoes, full s
# slice_6:  !daeha deeps lluf ,seodeprot eht nmaD
# slice_7:  eed ahead!
# slice_8:  Damn the torpedoes, full sp
# slice_9:   h opde,fl pe

# %%
text = "whatnow?"
text.upper()

"really?".upper()

text = "www1"
result1 = text.isdigit()
result1

text = "testing"
result = text.isalpha()
result
# Out:
# True

# %%
number1 = 1000
number2 = 24
plus_add = number1 + number2 + 15
result = plus_add**2
print("The final results of the calculation was:", result)
# Out:
# The final results of the calculation was: 1079521

# %% [markdown]
# In this exercise the aim is to try out different datatypes. Start by defining two variables, and assign the first variable the float value 10.6411. The second variable gets a string "Stringline!" as a value.
#
# Convert the first variable to an integer, and multiply the variable with the string by 2. After this, finalize the program to print out the results in the following way:

# %%
var1 = 10.6411
var2 = "Stringline!"
var1 = int(var1)
var2 = str(var2*2)
print("Integer conversion cannot do roundings:",var1)
print("Multiplying strings also causes trouble:",var2)
# Out:
# Integer conversion cannot do roundings: 10
# Multiplying strings also causes trouble: Stringline!Stringline!

# %% [markdown]
# >>>
#
# This here is divided to several lines:
# I am still in the same print-command.
# 	Name:	Peter
# 	Job:	Babysitter
# >>>

# %%
print("This here is divided to several lines: \nI am still in the same print-command.\n\tName:\tPeter\n\tJob:\tBabysitter")
# Out:
# This here is divided to several lines:
# I am still in the same print-command.
# 	Name:	Peter
# 	Job:	Babysitter

# %% [markdown]
# Calculator
# Give the first number: 100
# Give the second number: 25
# The result is: 125

# %%
print("Calculator")
num1 = input("Give the first number: ")
print("Give the first number: 6")
num2 = input("Give the second number: ")
print("Give the secound number: 7")
sum_result = int(num1) + int(num2)
print("The result is:", sum_result)
# Out:
# Calculator
# Give the first number: 6
# Give the secound number: 7
# The result is: 13

# %% [markdown]
# The last exercise in this chapter focuses on string slices. Define a variable and assign it a string "desserts" as a value. Then create three new variables, and assign them values by slicing the A) first 4 characters B) the last 4 characters and C) the entire string backwards as given values. Then make the program print the answers in the following way:
#
# The first 4 characters were: dess
# The last 4 characters were: erts
# The string backwards was: stressed

# %%
chat = "desserts"
lenght = len(chat)
slice_1 = chat[:4]
slice_2 = chat[-4::]
slice_3 = chat[::-1]

print("The first 4 characters were:", slice_1)
print("The last 4 characters were:", slice_2)
print("The string backwards was:", slice_3)
# Out:
# The first 4 characters were: dess
# The last 4 characters were: erts
# The string backwards was: stressed
